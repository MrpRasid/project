# %% [markdown]
# # Title: Fake News Detection using Machine Learning
# `Author:` [Md Mamun Rasid Prodhan](https://www.linkedin.com/in/mamun-rasid-prodhan/)\
# `Dataset:` [fake-news Data](https://www.kaggle.com/datasets/rajatkumar30/fake-news)

# %% [markdown]
# ## Meta Data (About Dataset)
# ## Context
# Fake news or hoax news is false or misleading information presented as news. Fake news often has the aim of damaging the reputation of a person or entity, or making money through advertising revenue.
#
# ## Problem Statement
# In today's digital world, misinformation spreads faster than ever. Fake news not only misleads people but can also harm individuals, organizations, and society.
#
# This project aims to build a robust Machine Learning model that can accurately classify news articles as Real or Fake based on textual content.
#
# ### Content
# ### Column Descriptions:
# 1) Title -> Title of the News
#
# 2) Text -> Text or Content of the News
#
# 3) Label -> Labelling the news as Fake or Real
#
# ## Aim:
# To design and build an intelligent Fake News Detection system that leverages Machine Learning and NLP to accurately distinguish between misinformation and authentic news, helping combat the growing threat of digital misinformation.
#
# ## Objective:
# - **Explore & Understand Data**\
# Dive deep into news articles to uncover patterns, trends, and differences between Fake and Real news.
#
# - **Transform Raw Text into Insights**\
# Apply advanced text preprocessing techniques to clean, structure, and prepare unstructured news content.
#
# - **Powerful Feature Engineering**\
# Convert textual data into meaningful numerical representations using TF-IDF, Bag of Words, and embeddings.
#
# - **Build Intelligent Models**\
# Develop and compare multiple ML models such as Logistic Regression, Naive Bayes, and Random Forest to achieve high accuracy.
#
# - **Optimize for Performance**\
# Enhance model reliability through hyperparameter tuning and cross-validation.
#
# - **Evaluate with Precision**\
# Measure effectiveness using key metrics like Accuracy, Precision, Recall, and F1-score to ensure robust performance.

# %% [markdown]
# # Import the required libraries

# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Download Stop-words:
# **Stop-words**: Stop words are commonly used words—such as "the," "is," "and," "in"

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# print the stop words 
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# ## import dataset
# kaggle link: https://www.kaggle.com/datasets/rajatkumar30/fake-news/data

# %%
df = pd.read_csv("C:\\Users\\HP\\newPython\\data_Science\\ML\\project\\Fake News Prediction using Machine Learning\\news.csv")
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
df.shape
# Out:
# (6335, 4)

# %% [markdown]
# ## Check The missing Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %% [markdown]
# ## Merge two colum title and text

# %%
df['content']=  df['title'] + ' '+ df['text']

# %%
df.head(1)
# Out:
#    Unnamed: 0                         title  \
# 0        8476  You Can Smell Hillary’s Fear
#
#                                                 text label  \
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
#
#                                              content
# 0  You Can Smell Hillary’s Fear Daniel Greenfield...

# %% [markdown]
# *There is no missing Values in this dataset

# %% [markdown]
# ## Separate the input and output Columns

# %%
x = df.drop(columns = 'label', axis = True)
y = df['label']

# %% [markdown]
# ### *Steming:
# Steming is the process of reducing a word to its Root word
#
# Ex: actor, actress, acting --> act

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]', ' ', content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
df['content'] = df['content'].apply(stemming)

# %%
print(df['content'])
# Out:
# 0       smell hillari fear daniel greenfield shillman ...
# 1       watch exact moment paul ryan commit polit suic...
# 2       kerri go pari gestur sympathi u secretari stat...
# 3       berni support twitter erupt anger dnc tri warn...
# 4       battl new york primari matter primari day new ...
#                               ...
# 6330    state depart say find email clinton specialist...
# 6331    p pb stand plutocrat pentagon p pb stand pluto...
# 6332    anti trump protest tool oligarchi inform anti ...
# 6333    ethiopia obama seek progress peac secur east a...
# 6334    jeb bush suddenli attack trump matter jeb bush...
# Name: content, Length: 6335, dtype: object

# %%
# sperate the data set 
x = df['content'].values
y = df['label'].values

# %%
print(x)
# Out:
# ['smell hillari fear daniel greenfield shillman journal fellow freedom center new york writer focus radic islam final stretch elect hillari rodham clinton gone war fbi word unpreced thrown around often elect ought retir still unpreced nomine major polit parti go war fbi exactli hillari peopl done coma patient wake watch hour cnn hospit bed would assum fbi director jame comey hillari oppon elect fbi attack everyon obama cnn hillari peopl circul letter attack comey current media hit piec lambast target trump surpris clinton alli start run attack ad fbi fbi leadership warn entir left wing establish form lynch mob continu go hillari fbi credibl attack media democrat preemptiv head result investig clinton foundat hillari clinton covert struggl fbi agent obama doj peopl gone explos public new york time compar comey j edgar hoover bizarr headlin jame comey role recal hoover fbi fairli practic admit front spout nonsens boston globe publish column call comey resign outdon time editori claim s
# ...

# %%
y
# Out:
# array(['FAKE', 'FAKE', 'REAL', ..., 'FAKE', 'REAL', 'REAL'], dtype=object)

# %% [markdown]
# ## convert the text data to numeric data

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(x)

x = vectorizer.transform(x)

# %% [markdown]
# ### Encode the label data using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
y = le.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %% [markdown]
# # Split the data for train and Test

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Train the model:

# %% [markdown]
# **Logistic Regression**

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Evalute The model

# %%
y_predict = model.predict(x_test)

# %% [markdown]
# ### Check Accuracy

# %%
accuracy = accuracy_score(y_test, y_predict)
print('Accuracy Score: ', accuracy)
# Out:
# Accuracy Score:  0.9163378058405682

# %% [markdown]
# # Make a predictive System

# %%
x_new = x_test[6]

prediction = model.predict(x_new)
print(prediction)

if (prediction[0] == 0):
    print('The news is Fake')
else:
    print('The news is Real')
# Out:
# [1]
# The news is Real

# %% [markdown]
# ## Results:
# - Achieved high accuracy in distinguishing fake and real news
# - Best model selected based on performance metrics
# - Model shows strong generalization capability
#
# ## Key Insights:
# - Fake news often contains exaggerated or emotionally charged words
# - Real news tends to be more structured and factual
# - Text patterns play a crucial role in classification
